# %%
from bitarray import bitarray
from bitarray.util import ba2int, int2ba
import json

# %%
def load_sbox(file_path="sbox_gost_28147_89.json"):
    with open(file_path, "r") as file:
        return json.load(file)["S_BOX"]

# %%
messages = 'VUONG_DUY'
key = '136205V'
S_BOX = load_sbox()

# %%
S_BOX
# Out:
# [[12, 4, 6, 2, 10, 5, 11, 9, 14, 8, 13, 7, 0, 3, 15, 1],
#  [6, 8, 2, 3, 9, 10, 5, 12, 1, 14, 4, 7, 11, 13, 0, 15],
#  [11, 3, 5, 8, 2, 15, 10, 13, 14, 1, 7, 4, 12, 9, 6, 0],
#  [12, 8, 2, 1, 13, 4, 15, 6, 7, 0, 10, 5, 3, 14, 9, 11],
#  [7, 15, 5, 10, 8, 1, 6, 13, 0, 9, 3, 14, 11, 4, 2, 12],
#  [5, 13, 15, 6, 9, 2, 12, 10, 11, 7, 8, 1, 4, 3, 14, 0],
#  [8, 14, 2, 5, 6, 9, 1, 12, 15, 4, 11, 0, 13, 10, 3, 7],
#  [1, 7, 14, 13, 0, 5, 8, 3, 4, 15, 10, 6, 9, 12, 11, 2]]

# %%
def hex_to_bin(hex_string):
    hex_string = hex_string.replace(" ", "")
    return bitarray(bin(int(hex_string, 16))[2:].zfill(len(hex_string) * 4))

# %%
def bin_to_hex(bin_array):
    """Chuyển đổi dữ liệu nhị phân thành chuỗi thập lục phân với định dạng mong muốn."""
    hex_string = format(ba2int(bin_array), 'X').zfill(len(bin_array) // 4)
    return ' '.join(hex_string[i:i+2] for i in range(0, len(hex_string), 2))

# %%
def str_to_block_64_bit(string):
    binary_string = bitarray()
    binary_string.frombytes(string.encode("ISO-8859-1"))
    padding = 64 - len(binary_string) % 64
    binary_string += bitarray(padding * "0")
    return [binary_string[i:i+64] for i in range(0, len(binary_string), 64)]

# %%
def block_64_bit_to_str(blocks):
    binary_string = bitarray()
    for block in blocks:
        binary_string += block
    return binary_string.tobytes().decode("ISO-8859-1")

# %%
def str_to_key_256_bit(string):
    binary_string = bitarray()
    binary_string.frombytes(string.encode("ISO-8859-1"))
    # lặp lại key cho đến khi đủ 256 bit
    while len(binary_string) < 256:
        binary_string += binary_string
    return binary_string[:256]

# %%
blocks = str_to_block_64_bit(messages)
key_256b = str_to_key_256_bit(key)
print(bin_to_hex(blocks[0]))
print(bin_to_hex(key_256b))
# Out:
# 56 55 4F 4E 47 5F 44 55
# 31 33 36 32 30 35 56 31 33 36 32 30 35 56 31 33 36 32 30 35 56 31 33 36 32 30 35 56 31 33 36 32

# %%
def generate_subkeys(key):
    subkeys = []
    for i in range(8):
        subkeys.append(key[i*32:(i+1)*32])
    return subkeys

# %%
generate_subkeys(key_256b)
# Out:
# [bitarray('00110001001100110011011000110010'),
#  bitarray('00110000001101010101011000110001'),
#  bitarray('00110011001101100011001000110000'),
#  bitarray('00110101010101100011000100110011'),
#  bitarray('00110110001100100011000000110101'),
#  bitarray('01010110001100010011001100110110'),
#  bitarray('00110010001100000011010101010110'),
#  bitarray('00110001001100110011011000110010')]

# %%
# phân chia các 8 khóa cho 32 vòng mã hóa
def generate_key_for_rounds(key):
    subkeys = generate_subkeys(key)
    keys_for_rounds = []
    for i in range(24):
        keys_for_rounds.append(subkeys[i % 8])
    for i in range(24, 32):
        keys_for_rounds.append(subkeys[7 - i % 8])
    return keys_for_rounds

# %%
generate_key_for_rounds(key_256b)
# Out:
# [bitarray('00110001001100110011011000110010'),
#  bitarray('00110000001101010101011000110001'),
#  bitarray('00110011001101100011001000110000'),
#  bitarray('00110101010101100011000100110011'),
#  bitarray('00110110001100100011000000110101'),
#  bitarray('01010110001100010011001100110110'),
#  bitarray('00110010001100000011010101010110'),
#  bitarray('00110001001100110011011000110010'),
#  bitarray('00110001001100110011011000110010'),
#  bitarray('00110000001101010101011000110001'),
#  bitarray('00110011001101100011001000110000'),
#  bitarray('00110101010101100011000100110011'),
#  bitarray('00110110001100100011000000110101'),
#  bitarray('01010110001100010011001100110110'),
#  bitarray('00110010001100000011010101010110'),
#  bitarray('00110001001100110011011000110010'),
#  bitarray('00110001001100110011011000110010'),
#  bitarray('00110000001101010101011000110001'),
#  bitarray('00110011001101100011001000110000'),
#  bitarray('00110101010101100011000100110011'),
#  bitarray('00110110001100100011000000110101'),
#  bitarray('01010110001100010011001100110110'),
#  bitarray('00110010001100000011010101010110'),
#  bitarray('00110001001100110011011000110010'),
#  bitarray('00110001001100110011011000110010'),
#  bitarray('00110010001100000011010101010110'),
#  bitarray('01010110001100010011001100110110'),
#  bitarray('00110110001100100011000000110101'),
#  bitarray('00110101010101100011000100110011'),
#  bitarray('00110011001101100011001000110000'),
#  bitarray('00110000001101010101011000110001'),
#  bitarray('00110001001100110011011000110010')]

# %%
def apply_sbox(block, sbox):
    for i in range(8):
        index = ba2int(block[i*4:(i+1)*4])
        block[i*4:(i+1)*4] = int2ba(sbox[7-i][index], length=4)
    return block

# %%
# dịch bit sang trái 11 bit
def shift_11_bits_left(block):
    return block[11:] + block[:11]

# %%
def bitwise_addition_32bit(right_ba, subkey_ba):
    """
    Thực hiện phép cộng nhị phân modulo 2^32 giữa hai bitarray 32-bit.
    """
    right_int = ba2int(right_ba)
    key_round_int = ba2int(subkey_ba)
    print(f"Right: {right_ba.to01()}")
    print(f"Key: {subkey_ba.to01()}")

    # Cộng số nguyên và lấy modulo 2^32
    result_int = (right_int + key_round_int) % (2**32)

    # Chuyển đổi lại thành bitarray 32-bit
    result_ba = int2ba(result_int, length=32)
    print(f"Result: {result_ba.to01()}")

    return result_ba

# %%
def f_function(right, key_round):
    right = bitwise_addition_32bit(right, key_round)
    print(f"Right after addition: {bin_to_hex(right)}")
    right = apply_sbox(right, S_BOX)
    print(f"Right after S-Box: {bin_to_hex(right)}")
    right = shift_11_bits_left(right)
    print(f"Right after shift: {bin_to_hex(right)}")
    return right

# %%
def MAGMA_round(left, right, key_round):
    next_left = right
    next_right = left ^ f_function(right, key_round)
    return next_left, next_right

# %%
def MAGMA_cipher_block(block, key_for_rounds, encrypt=True):
    left, right = block[:32], block[32:]
    key_for_rounds = key_for_rounds if encrypt else key_for_rounds[::-1]
    
    results = []
    for key_round in key_for_rounds:
        left, right = MAGMA_round(left, right, key_round)
        results.append((left.copy(), right.copy(), key_round.copy()))
        
    final_result = right + left
    return final_result, results

# %%
def MAGMA_cipher(messages, key, encrypt=True):
    blocks = str_to_block_64_bit(messages)
    key_256b = str_to_key_256_bit(key)
    key_for_rounds = generate_key_for_rounds(key_256b)
    res_blocks = []
    for block in blocks:
        res_block, _ = MAGMA_cipher_block(block, key_for_rounds, encrypt)
        res_blocks.append(res_block)
    result = block_64_bit_to_str(res_blocks)
    return result

# %%
cipher_text = MAGMA_cipher(messages, key, encrypt=True)
print(cipher_text)
plain_text = MAGMA_cipher(cipher_text, key, encrypt=False)
print(plain_text)
# Out:
# Right: 01000111010111110100010001010101
# Key: 00110001001100110011011000110010
# Result: 01111000100100100111101010000111
# Right after addition: 78 92 7A 87
# Right after S-Box: 3F 75 67 19
# Right after shift: AB 38 C9 FB
# Right: 11111101011011011000011010110101
# Key: 00110000001101010101011000110001
# Result: 00101101101000101101110011100110
# Right after addition: 2D A2 DC E6
# Right after S-Box: EA 85 EC 0B
# Right after shift: 2F 60 5F 54
# Right: 01101000001111110001101100000001
# Key: 00110011001101100011001000110000
# Result: 10011011011101010100110100110001
# Right after addition: 9B 75 4D 31
# Right after S-Box: F0 A1 D9 34
# Right after shift: 0E C9 A7 85
# Right: 11110011101001000010000100110000
# Key: 00110101010101100011000100110011
# Result: 00101000111110100101001001100011
# Right after addition: 28 FA 52 63
# Right after S-Box: EF 03 45 52
# Right after shift: 1A 2A 97 78
# Right: 01110010000101011000110001111001
# Key: 00110110001100100011000000110101
# Result: 10101000010001111011110010101110
# Right after addition: A8 47 BC AE
# Right after S-Box: AF 9D 5C 4F
# Right after shift: EA E2 7D 7C
# Right: 00011001010001100101110001001100
# Key: 01010110001100010011001100110110
# Result: 01101111011101111000111110000010
# Right after addition: 6F 77 8F 82
# Right after S-Box: 87 AD 70 16
# Right after shift: 6B 80 B4 3D
# Right: 00011001100101010011100001000100
# Key: 00110010001100000011010101010110
# Result: 01001011110001010110110110011010
# Right after addition: 4B C5 6D 9A
# Right after S-Box: 00 41 F9 ED
# Right after shift: 0F CF 68 02
# Right: 00010110100010010011010001001110
# Key: 00110001001100110011011000110010
# Result: 01000111101111000110101010000000
# Right after addition: 47 BC 6A 80
# Right after S-Box: 0C 1B F7 1C
# Right after shift: DF B8 E0 60
# Right: 11000110001011011101100000100100
# Key: 00110001001100110011011000110010
# Result: 11110111011000010000111001010110
# Right after addition: F7 61 0E 56
# Right after S-Box: 2C CF C6 AB
# Right after shift: 7E 35 59 66
# Right: 01101000101111000110110100101000
# Key: 00110000001101010101011000110001
# Result: 10011000111100011100001101011001
# Right after addition: 98 F1 C3 59
# Right after S-Box: FF 0F 38 A8
# Right after shift: 79 C5 47 F8
# Right: 10111111111010001001111111011100
# Key: 00110011001101100011001000110000
# Result: 11110011000111101101001000001100
# Right after addition: F3 1E D2 0C
# Right after S-Box: 25 D2 E5 60
# Right after shift: 97 2B 01 2E
# Right: 11111111100101110110110000000110
# Key: 00110101010101100011000100110011
# Result: 00110100111011011001110100111001
# Right after addition: 34 ED 9D 39
# Right after S-Box: D6 E4 09 38
# Right after shift: 20 49 C6 B7
# Right: 10011111101000010101100101101011
# Key: 00110110001100100011000000110101
# Result: 11010101110100111000100110100000
# Right after addition: D5 D3 89 A0
# Right after S-Box: C9 3A 71 4C
# Right after shift: D3 8A 66 49
# Right: 00101100000111010000101001001111
# Key: 01010110001100010011001100110110
# Result: 10000010010011100011110110000101
# Right after addition: 82 4E 3D 85
# Right after S-Box: 42 92 19 15
# Right after shift: 90 C8 AA 14
# Right: 00001111011010011111001101111111
# Key: 00110010001100000011010101010110
# Result: 01000001100110100010100011010101
# Right after addition: 41 9A 28 D5
# Right after S-Box: 0E 73 2E D5
# Right after shift: 99 76 A8 73
# Right: 10110101011010111010001000111100
# Key: 00110001001100110011011000110010
# Result: 11100110100111101101100001101110
# Right after addition: E6 9E D8 6E
# Right after S-Box: B1 72 EE 5F
# Right after shift: 97 72 FD 8B
# Right: 10011000000110110000111011110100
# Key: 00110001001100110011011000110010
# Result: 11001001010011100100010100100110
# Right after addition: C9 4E 45 26
# Right after S-Box: 94 92 DF 2B
# Right after shift: 96 F9 5C A4
# Right: 00100011100100101111111010011000
# Key: 00110000001101010101011000110001
# Result: 01010011110010000101010011001001
# Right after addition: 53 C8 54 C9
# Right after S-Box: 55 40 42 B8
# Right after shift: 02 15 C2 AA
# Right: 10011010000011101100110001011110
# Key: 00110011001101100011001000110000
# Result: 11001101010001001111111010001110
# Right after addition: CD 44 FE 8E
# Right after S-Box: 9A 98 B6 1F
# Right after shift: C5 B0 FC D4
# Right: 11100110001000100000001001001100
# Key: 00110101010101100011000100110011
# Result: 00011011011110000011001101111111
# Right after addition: 1B 78 33 7F
# Right after S-Box: 70 A0 18 C1
# Right after shift: 00 C6 0B 85
# Right: 10011010110010001100011111011011
# Key: 00110110001100100011000000110101
# Result: 11010000111110101111100000010000
# Right after addition: D0 FA F8 10
# Right after S-Box: C8 03 BE 8C
# Right after shift: 1D F4 66 40
# Right: 11111011110101100110010000001100
# Key: 01010110001100010011001100110110
# Result: 01010010000001111001011101000010
# Right after addition: 52 07 97 42
# Right after S-Box: 52 5D 0D 96
# Right after shift: E8 6C B2 92
# Right: 01110010101001000111010101001001
# Key: 00110010001100000011010101010110
# Result: 10100100110101001010101010011111
# Right after addition: A4 D4 AA 9F
# Right after S-Box: A6 38 A7 E1
# Right after shift: C5 3F 0D 31
# Right: 00111110111010010110100100111101
# Key: 00110001001100110011011000110010
# Result: 01110000000111001001111101101111
# Right after addition: 70 1C 9F 6F
# Right after S-Box: 38 DB 00 51
# Right after shift: D8 02 89 C6
# Right: 10101010101001101111110010001111
# Key: 00110001001100110011011000110010
# Result: 11011011110110100011001011000001
# Right after addition: DB DA 32 C1
# Right after S-Box: C0 33 15 B4
# Right after shift: 98 AD A6 01
# Right: 10100110010001001100111100111100
# Key: 00110010001100000011010101010110
# Result: 11011000011101010000010010010010
# Right after addition: D8 75 04 92
# Right after S-Box: CF A1 C2 E6
# Right after shift: 0E 17 36 7D
# Right: 10100100101100011100101011110010
# Key: 01010110001100010011001100110110
# Result: 11111010111000101111111000101000
# Right after addition: FA E2 FE 28
# Right after S-Box: 2B E5 B6 2E
# Right after shift: 2D B1 71 5F
# Right: 10001011111101011011111001100011
# Key: 00110110001100100011000000110101
# Result: 11000010001001111110111010011000
# Right after addition: C2 27 EE 98
# Right after S-Box: 92 FD 96 EE
# Right after shift: EC B7 74 97
# Right: 01001000000001101011111001100101
# Key: 00110101010101100011000100110011
# Result: 01111101010111001110111110011000
# Right after addition: 7D 5C EF 98
# Right after S-Box: 3A 2B 90 EE
# Right after shift: 5C 87 71 D1
# Right: 11010111011100101100111110110010
# Key: 00110011001101100011001000110000
# Result: 00001010101010010000000111100010
# Right after addition: 0A A9 01 E2
# Right after S-Box: 1B 89 C3 06
# Right after shift: 4E 18 30 DC
# Right: 00000110000111101000111010111001
# Key: 00110000001101010101011000110001
# Result: 00110110010100111110010011101010
# Right after addition: 36 53 E4 EA
# Right after S-Box: D1 2A 92 0D
# Right after shift: 54 90 6E 89
# Right: 10000011111000101010000100111011
# Key: 00110001001100110011011000110010
# Result: 10110101000101011101011101101101
# Right after addition: B5 15 D7 6D
# Right after S-Box: 69 D1 ED 53
# Right after shift: 8F 6A 9B 4E
# Right: 00000000000000000000000000000000
# Key: 00110001001100110011011000110010
# Result: 00110001001100110011011000110010
# Right after addition: 31 33 36 32
# Right after S-Box: DE 6A 1A 36
# Right after shift: 50 D1 B6 F3
# Right: 00001001110100011011011011110011
# Key: 00110000001101010101011000110001
# Result: 00111010000001110000110100100100
# Right after addition: 3A 07 0D 24
# Right after S-Box: DB 5D C9 2A
# Right after shift: EE 49 56 DA
# Right: 11101110010010010101011011011010
# Key: 00110011001101100011001000110000
# Result: 00100001011111111000100100001010
# Right after addition: 21 7F 89 0A
# Right after S-Box: EE AC 71 6D
# Right after shift: 63 8B 6F 75
# Right: 01101010010110101101100110000110
# Key: 00110101010101100011000100110011
# Result: 10011111101100010000101010111001
# Right after addition: 9F B1 0A B9
# Right after S-Box: F7 1F C7 78
# Right after shift: FE 3B C7 B8
# Right: 00010000011100101001000101100010
# Key: 00110110001100100011000000110101
# Result: 01000110101001001100000110010111
# Right after addition: 46 A4 C1 97
# Right after S-Box: 01 88 33 E9
# Right after shift: 41 9F 48 0C
# Right: 00101011110001011001000110001010
# Key: 01010110001100010011001100110110
# Result: 10000001111101101100010011000000
# Right after addition: 81 F6 C4 C0
# Right after S-Box: 4E 06 32 BC
# Right after shift: 31 95 E2 70
# Right: 00100001111001110111001100010010
# Key: 00110010001100000011010101010110
# Result: 01010100000101111010100001101000
# Right after addition: 54 17 A8 68
# Right after S-Box: 56 DD AE 5E
# Right after shift: ED 72 F2 B6
# Right: 11000110101101110110001100111100
# Key: 00110001001100110011011000110010
# Result: 11110111111010101001100101101110
# Right after addition: F7 EA 99 6E
# Right after S-Box: 2C E3 01 5F
# Right after shift: 18 0A F9 67
# Right: 00111001111011011000101001110101
# Key: 00110001001100110011011000110010
# Result: 01101011001000001100000010100111
# Right after addition: 6B 20 C0 A7
# Right after S-Box: 80 F7 3B 49
# Right after shift: B9 DA 4C 07
# Right: 01111111011011010010111100111011
# Key: 00110000001101010101011000110001
# Result: 10101111101000101000010101101100
# Right after addition: AF A2 85 6C
# Right after S-Box: A7 85 7F 50
# Right after shift: 2B FA 85 3C
# Right: 00010010000101110000111101001001
# Key: 00110011001101100011001000110000
# Result: 01000101010011010100000101111001
# Right after addition: 45 4D 41 79
# Right after S-Box: 09 94 D3 C8
# Right after shift: A6 9E 40 4C
# Right: 11011001111100110110111101110111
# Key: 00110101010101100011000100110011
# Result: 00001111010010011010000010101010
# Right after addition: 0F 49 A0 AA
# Right after S-Box: 17 99 AB 4D
# Right after shift: CD 5A 68 BC
# Right: 11011111010011010110011111110101
# Key: 00110110001100100011000000110101
# Result: 00010101011111111001100000101010
# Right after addition: 15 7F 98 2A
# Right after S-Box: 79 AC 0E 2D
# Right after shift: 60 71 6B CD
# Right: 10111001100000100000010010111010
# Key: 01010110001100010011001100110110
# Result: 00001111101100110011011111110000
# Right after addition: 0F B3 37 F0
# Right after S-Box: 17 1A 1D FC
# Right after shift: D0 EF E0 B8
# Right: 00001111101000101000011101001101
# Key: 00110010001100000011010101010110
# Result: 01000001110100101011110010100011
# Right after addition: 41 D2 BC A3
# Right after S-Box: 0E 35 5C 42
# Right after shift: AA E2 10 71
# Right: 00010011011000000001010011001011
# Key: 00110001001100110011011000110010
# Result: 01000100100100110100101011111101
# Right after addition: 44 93 4A FD
# Right after S-Box: 06 7A D7 F3
# Right after shift: D6 BF 98 33
# Right: 11011001000111010001111101111110
# Key: 00110001001100110011011000110010
# Result: 00001010010100000101010110110000
# Right after addition: 0A 50 55 B0
# Right after S-Box: 1B 27 4F 7C
# Right after shift: 3A 7B E0 D9
# Right: 00101001000110111111010000010010
# Key: 00110000001101010101011000110001
# Result: 01011001010100010100101001000011
# Right after addition: 59 51 4A 43
# Right after S-Box: 54 2F D7 92
# Right after shift: 7E BC 92 A1
# Right: 10100111101000011000110111011111
# Key: 00110011001101100011001000110000
# Result: 11011010110101111100000000001111
# Right after addition: DA D7 C0 0F
# Right after S-Box: CB 3D 3B 61
# Right after shift: E9 DB 0E 59
# Right: 11000000110000001111101001001011
# Key: 00110101010101100011000100110011
# Result: 11110110000101110010101101111110
# Right after addition: F6 17 2B 7E
# Right after S-Box: 21 DD 24 CF
# Right after shift: E9 26 79 0E
# Right: 01001110100001111111010011010001
# Key: 00110110001100100011000000110101
# Result: 10000100101110100010010100000110
# Right after addition: 84 BA 25 06
# Right after S-Box: 46 13 2F 6B
# Right after shift: 99 7B 5A 30
# Right: 01011001101110111010000001111011
# Key: 01010110001100010011001100110110
# Result: 10101111111011001101001110110001
# Right after addition: AF EC D3 B1
# Right after S-Box: A7 EB E8 74
# Right after shift: 5F 43 A5 3F
# Right: 00010001110001000101000111101110
# Key: 00110010001100000011010101010110
# Result: 01000011111101001000011101000100
# Right after addition: 43 F4 87 44
# Right after S-Box: 05 08 7D 9A
# Right after shift: 43 EC D0 28
# Right: 00011010010101110111000001010011
# Key: 00110001001100110011011000110010
# Result: 01001011100010101010011010000101
# Right after addition: 4B 8A A6 85
# Right after S-Box: 00 B3 AA 15
# Right after shift: 9D 50 A8 05
# Right: 10001100100101001111100111101011
# Key: 00110001001100110011011000110010
# Result: 10111101110010000011000000011101
# Right after addition: BD C8 30 1D
# Right after S-Box: 6A 40 1B 83
# Right after shift: 00 DC 1B 52
# Right: 00011010100010110110101100000001
# Key: 00110010001100000011010101010110
# Result: 01001100101110111010000001010111
# Right after addition: 4C BB A0 57
# Right after S-Box: 0D 1E AB A9
# Right after shift: F5 5D 48 68
# Right: 01111001110010011011000110000011
# Key: 01010110001100010011001100110110
# Result: 11001111111110101110010010111001
# Right after addition: CF FA E4 B9
# Right after S-Box: 97 03 92 78
# Right after shift: 1C 93 C4 B8
# Right: 00000110000110001010111110111001
# Key: 00110110001100100011000000110101
# Result: 00111100010010101101111111101110
# Right after addition: 3C 4A DF EE
# Right after S-Box: DD 93 E0 0F
# Right after shift: 9F 00 7E EC
# Right: 11100110110010011100111101101111
# Key: 00110101010101100011000100110011
# Result: 00011100001000000000000010100010
# Right after addition: 1C 20 00 A2
# Right after S-Box: 7D F7 CB 46
# Right after shift: BE 5A 33 EF
# Right: 10111000010000101001110001010110
# Key: 00110011001101100011001000110000
# Result: 11101011011110001100111010000110
# Right after addition: EB 78 CE 86
# Right after S-Box: B0 A0 36 1B
# Right after shift: 01 B0 DD 85
# Right: 11100111011110010001001011101010
# Key: 00110000001101010101011000110001
# Result: 00010111101011100110100100011011
# Right after addition: 17 AE 69 1B
# Right after S-Box: 7C 82 F1 87
# Right after shift: 17 8C 3B E4
# Right: 10101111110011101010011110110010
# Key: 00110001001100110011011000110010
# Result: 11100001000000011101110111100100
# Right after addition: E1 01 DD E4
# Right after S-Box: BE 5F E9 0A
# Right after shift: FF 48 55 F2
# t÷â¡;1G¯Î§²
# Right: 10000011111000101010000100111011
# Key: 00110001001100110011011000110010
# Result: 10110101000101011101011101101101
# Right after addition: B5 15 D7 6D
# Right after S-Box: 69 D1 ED 53
# Right after shift: 8F 6A 9B 4E
# Right: 00000110000111101000111010111001
# Key: 00110000001101010101011000110001
# Result: 00110110010100111110010011101010
# Right after addition: 36 53 E4 EA
# Right after S-Box: D1 2A 92 0D
# Right after shift: 54 90 6E 89
# Right: 11010111011100101100111110110010
# Key: 00110011001101100011001000110000
# Result: 00001010101010010000000111100010
# Right after addition: 0A A9 01 E2
# Right after S-Box: 1B 89 C3 06
# Right after shift: 4E 18 30 DC
# Right: 01001000000001101011111001100101
# Key: 00110101010101100011000100110011
# Result: 01111101010111001110111110011000
# Right after addition: 7D 5C EF 98
# Right after S-Box: 3A 2B 90 EE
# Right after shift: 5C 87 71 D1
# Right: 10001011111101011011111001100011
# Key: 00110110001100100011000000110101
# Result: 11000010001001111110111010011000
# Right after addition: C2 27 EE 98
# Right after S-Box: 92 FD 96 EE
# Right after shift: EC B7 74 97
# Right: 10100100101100011100101011110010
# Key: 01010110001100010011001100110110
# Result: 11111010111000101111111000101000
# Right after addition: FA E2 FE 28
# Right after S-Box: 2B E5 B6 2E
# Right after shift: 2D B1 71 5F
# Right: 10100110010001001100111100111100
# Key: 00110010001100000011010101010110
# Result: 11011000011101010000010010010010
# Right after addition: D8 75 04 92
# Right after S-Box: CF A1 C2 E6
# Right after shift: 0E 17 36 7D
# Right: 10101010101001101111110010001111
# Key: 00110001001100110011011000110010
# Result: 11011011110110100011001011000001
# Right after addition: DB DA 32 C1
# Right after S-Box: C0 33 15 B4
# Right after shift: 98 AD A6 01
# Right: 00111110111010010110100100111101
# Key: 00110001001100110011011000110010
# Result: 01110000000111001001111101101111
# Right after addition: 70 1C 9F 6F
# Right after S-Box: 38 DB 00 51
# Right after shift: D8 02 89 C6
# Right: 01110010101001000111010101001001
# Key: 00110010001100000011010101010110
# Result: 10100100110101001010101010011111
# Right after addition: A4 D4 AA 9F
# Right after S-Box: A6 38 A7 E1
# Right after shift: C5 3F 0D 31
# Right: 11111011110101100110010000001100
# Key: 01010110001100010011001100110110
# Result: 01010010000001111001011101000010
# Right after addition: 52 07 97 42
# Right after S-Box: 52 5D 0D 96
# Right after shift: E8 6C B2 92
# Right: 10011010110010001100011111011011
# Key: 00110110001100100011000000110101
# Result: 11010000111110101111100000010000
# Right after addition: D0 FA F8 10
# Right after S-Box: C8 03 BE 8C
# Right after shift: 1D F4 66 40
# Right: 11100110001000100000001001001100
# Key: 00110101010101100011000100110011
# Result: 00011011011110000011001101111111
# Right after addition: 1B 78 33 7F
# Right after S-Box: 70 A0 18 C1
# Right after shift: 00 C6 0B 85
# Right: 10011010000011101100110001011110
# Key: 00110011001101100011001000110000
# Result: 11001101010001001111111010001110
# Right after addition: CD 44 FE 8E
# Right after S-Box: 9A 98 B6 1F
# Right after shift: C5 B0 FC D4
# Right: 00100011100100101111111010011000
# Key: 00110000001101010101011000110001
# Result: 01010011110010000101010011001001
# Right after addition: 53 C8 54 C9
# Right after S-Box: 55 40 42 B8
# Right after shift: 02 15 C2 AA
# Right: 10011000000110110000111011110100
# Key: 00110001001100110011011000110010
# Result: 11001001010011100100010100100110
# Right after addition: C9 4E 45 26
# Right after S-Box: 94 92 DF 2B
# Right after shift: 96 F9 5C A4
# Right: 10110101011010111010001000111100
# Key: 00110001001100110011011000110010
# Result: 11100110100111101101100001101110
# Right after addition: E6 9E D8 6E
# Right after S-Box: B1 72 EE 5F
# Right after shift: 97 72 FD 8B
# Right: 00001111011010011111001101111111
# Key: 00110010001100000011010101010110
# Result: 01000001100110100010100011010101
# Right after addition: 41 9A 28 D5
# Right after S-Box: 0E 73 2E D5
# Right after shift: 99 76 A8 73
# Right: 00101100000111010000101001001111
# Key: 01010110001100010011001100110110
# Result: 10000010010011100011110110000101
# Right after addition: 82 4E 3D 85
# Right after S-Box: 42 92 19 15
# Right after shift: 90 C8 AA 14
# Right: 10011111101000010101100101101011
# Key: 00110110001100100011000000110101
# Result: 11010101110100111000100110100000
# Right after addition: D5 D3 89 A0
# Right after S-Box: C9 3A 71 4C
# Right after shift: D3 8A 66 49
# Right: 11111111100101110110110000000110
# Key: 00110101010101100011000100110011
# Result: 00110100111011011001110100111001
# Right after addition: 34 ED 9D 39
# Right after S-Box: D6 E4 09 38
# Right after shift: 20 49 C6 B7
# Right: 10111111111010001001111111011100
# Key: 00110011001101100011001000110000
# Result: 11110011000111101101001000001100
# Right after addition: F3 1E D2 0C
# Right after S-Box: 25 D2 E5 60
# Right after shift: 97 2B 01 2E
# Right: 01101000101111000110110100101000
# Key: 00110000001101010101011000110001
# Result: 10011000111100011100001101011001
# Right after addition: 98 F1 C3 59
# Right after S-Box: FF 0F 38 A8
# Right after shift: 79 C5 47 F8
# Right: 11000110001011011101100000100100
# Key: 00110001001100110011011000110010
# Result: 11110111011000010000111001010110
# Right after addition: F7 61 0E 56
# Right after S-Box: 2C CF C6 AB
# Right after shift: 7E 35 59 66
# Right: 00010110100010010011010001001110
# Key: 00110001001100110011011000110010
# Result: 01000111101111000110101010000000
# Right after addition: 47 BC 6A 80
# Right after S-Box: 0C 1B F7 1C
# Right after shift: DF B8 E0 60
# Right: 00011001100101010011100001000100
# Key: 00110010001100000011010101010110
# Result: 01001011110001010110110110011010
# Right after addition: 4B C5 6D 9A
# Right after S-Box: 00 41 F9 ED
# Right after shift: 0F CF 68 02
# Right: 00011001010001100101110001001100
# Key: 01010110001100010011001100110110
# Result: 01101111011101111000111110000010
# Right after addition: 6F 77 8F 82
# Right after S-Box: 87 AD 70 16
# Right after shift: 6B 80 B4 3D
# Right: 01110010000101011000110001111001
# Key: 00110110001100100011000000110101
# Result: 10101000010001111011110010101110
# Right after addition: A8 47 BC AE
# Right after S-Box: AF 9D 5C 4F
# Right after shift: EA E2 7D 7C
# Right: 11110011101001000010000100110000
# Key: 00110101010101100011000100110011
# Result: 00101000111110100101001001100011
# Right after addition: 28 FA 52 63
# Right after S-Box: EF 03 45 52
# Right after shift: 1A 2A 97 78
# Right: 01101000001111110001101100000001
# Key: 00110011001101100011001000110000
# Result: 10011011011101010100110100110001
# Right after addition: 9B 75 4D 31
# Right after S-Box: F0 A1 D9 34
# Right after shift: 0E C9 A7 85
# Right: 11111101011011011000011010110101
# Key: 00110000001101010101011000110001
# Result: 00101101101000101101110011100110
# Right after addition: 2D A2 DC E6
# Right after S-Box: EA 85 EC 0B
# Right after shift: 2F 60 5F 54
# Right: 01000111010111110100010001010101
# Key: 00110001001100110011011000110010
# Result: 01111000100100100111101010000111
# Right after addition: 78 92 7A 87
# Right after S-Box: 3F 75 67 19
# Right after shift: AB 38 C9 FB
# Right: 10101111110011101010011110110010
# Key: 00110001001100110011011000110010
# Result: 11100001000000011101110111100100
# Right after addition: E1 01 DD E4
# Right after S-Box: BE 5F E9 0A
# Right after shift: FF 48 55 F2
# Right: 11100111011110010001001011101010
# Key: 00110000001101010101011000110001
# Result: 00010111101011100110100100011011
# Right after addition: 17 AE 69 1B
# Right after S-Box: 7C 82 F1 87
# Right after shift: 17 8C 3B E4
# Right: 10111000010000101001110001010110
# Key: 00110011001101100011001000110000
# Result: 11101011011110001100111010000110
# Right after addition: EB 78 CE 86
# Right after S-Box: B0 A0 36 1B
# Right after shift: 01 B0 DD 85
# Right: 11100110110010011100111101101111
# Key: 00110101010101100011000100110011
# Result: 00011100001000000000000010100010
# Right after addition: 1C 20 00 A2
# Right after S-Box: 7D F7 CB 46
# Right after shift: BE 5A 33 EF
# Right: 00000110000110001010111110111001
# Key: 00110110001100100011000000110101
# Result: 00111100010010101101111111101110
# Right after addition: 3C 4A DF EE
# Right after S-Box: DD 93 E0 0F
# Right after shift: 9F 00 7E EC
# Right: 01111001110010011011000110000011
# Key: 01010110001100010011001100110110
# Result: 11001111111110101110010010111001
# Right after addition: CF FA E4 B9
# Right after S-Box: 97 03 92 78
# Right after shift: 1C 93 C4 B8
# Right: 00011010100010110110101100000001
# Key: 00110010001100000011010101010110
# Result: 01001100101110111010000001010111
# Right after addition: 4C BB A0 57
# Right after S-Box: 0D 1E AB A9
# Right after shift: F5 5D 48 68
# Right: 10001100100101001111100111101011
# Key: 00110001001100110011011000110010
# Result: 10111101110010000011000000011101
# Right after addition: BD C8 30 1D
# Right after S-Box: 6A 40 1B 83
# Right after shift: 00 DC 1B 52
# Right: 00011010010101110111000001010011
# Key: 00110001001100110011011000110010
# Result: 01001011100010101010011010000101
# Right after addition: 4B 8A A6 85
# Right after S-Box: 00 B3 AA 15
# Right after shift: 9D 50 A8 05
# Right: 00010001110001000101000111101110
# Key: 00110010001100000011010101010110
# Result: 01000011111101001000011101000100
# Right after addition: 43 F4 87 44
# Right after S-Box: 05 08 7D 9A
# Right after shift: 43 EC D0 28
# Right: 01011001101110111010000001111011
# Key: 01010110001100010011001100110110
# Result: 10101111111011001101001110110001
# Right after addition: AF EC D3 B1
# Right after S-Box: A7 EB E8 74
# Right after shift: 5F 43 A5 3F
# Right: 01001110100001111111010011010001
# Key: 00110110001100100011000000110101
# Result: 10000100101110100010010100000110
# Right after addition: 84 BA 25 06
# Right after S-Box: 46 13 2F 6B
# Right after shift: 99 7B 5A 30
# Right: 11000000110000001111101001001011
# Key: 00110101010101100011000100110011
# Result: 11110110000101110010101101111110
# Right after addition: F6 17 2B 7E
# Right after S-Box: 21 DD 24 CF
# Right after shift: E9 26 79 0E
# Right: 10100111101000011000110111011111
# Key: 00110011001101100011001000110000
# Result: 11011010110101111100000000001111
# Right after addition: DA D7 C0 0F
# Right after S-Box: CB 3D 3B 61
# Right after shift: E9 DB 0E 59
# Right: 00101001000110111111010000010010
# Key: 00110000001101010101011000110001
# Result: 01011001010100010100101001000011
# Right after addition: 59 51 4A 43
# Right after S-Box: 54 2F D7 92
# Right after shift: 7E BC 92 A1
# Right: 11011001000111010001111101111110
# Key: 00110001001100110011011000110010
# Result: 00001010010100000101010110110000
# Right after addition: 0A 50 55 B0
# Right after S-Box: 1B 27 4F 7C
# Right after shift: 3A 7B E0 D9
# Right: 00010011011000000001010011001011
# Key: 00110001001100110011011000110010
# Result: 01000100100100110100101011111101
# Right after addition: 44 93 4A FD
# Right after S-Box: 06 7A D7 F3
# Right after shift: D6 BF 98 33
# Right: 00001111101000101000011101001101
# Key: 00110010001100000011010101010110
# Result: 01000001110100101011110010100011
# Right after addition: 41 D2 BC A3
# Right after S-Box: 0E 35 5C 42
# Right after shift: AA E2 10 71
# Right: 10111001100000100000010010111010
# Key: 01010110001100010011001100110110
# Result: 00001111101100110011011111110000
# Right after addition: 0F B3 37 F0
# Right after S-Box: 17 1A 1D FC
# Right after shift: D0 EF E0 B8
# Right: 11011111010011010110011111110101
# Key: 00110110001100100011000000110101
# Result: 00010101011111111001100000101010
# Right after addition: 15 7F 98 2A
# Right after S-Box: 79 AC 0E 2D
# Right after shift: 60 71 6B CD
# Right: 11011001111100110110111101110111
# Key: 00110101010101100011000100110011
# Result: 00001111010010011010000010101010
# Right after addition: 0F 49 A0 AA
# Right after S-Box: 17 99 AB 4D
# Right after shift: CD 5A 68 BC
# Right: 00010010000101110000111101001001
# Key: 00110011001101100011001000110000
# Result: 01000101010011010100000101111001
# Right after addition: 45 4D 41 79
# Right after S-Box: 09 94 D3 C8
# Right after shift: A6 9E 40 4C
# Right: 01111111011011010010111100111011
# Key: 00110000001101010101011000110001
# Result: 10101111101000101000010101101100
# Right after addition: AF A2 85 6C
# Right after S-Box: A7 85 7F 50
# Right after shift: 2B FA 85 3C
# Right: 00111001111011011000101001110101
# Key: 00110001001100110011011000110010
# Result: 01101011001000001100000010100111
# Right after addition: 6B 20 C0 A7
# Right after S-Box: 80 F7 3B 49
# Right after shift: B9 DA 4C 07
# Right: 11000110101101110110001100111100
# Key: 00110001001100110011011000110010
# Result: 11110111111010101001100101101110
# Right after addition: F7 EA 99 6E
# Right after S-Box: 2C E3 01 5F
# Right after shift: 18 0A F9 67
# Right: 00100001111001110111001100010010
# Key: 00110010001100000011010101010110
# Result: 01010100000101111010100001101000
# Right after addition: 54 17 A8 68
# Right after S-Box: 56 DD AE 5E
# Right after shift: ED 72 F2 B6
# Right: 00101011110001011001000110001010
# Key: 01010110001100010011001100110110
# Result: 10000001111101101100010011000000
# Right after addition: 81 F6 C4 C0
# Right after S-Box: 4E 06 32 BC
# Right after shift: 31 95 E2 70
# Right: 00010000011100101001000101100010
# Key: 00110110001100100011000000110101
# Result: 01000110101001001100000110010111
# Right after addition: 46 A4 C1 97
# Right after S-Box: 01 88 33 E9
# Right after shift: 41 9F 48 0C
# Right: 01101010010110101101100110000110
# Key: 00110101010101100011000100110011
# Result: 10011111101100010000101010111001
# Right after addition: 9F B1 0A B9
# Right after S-Box: F7 1F C7 78
# Right after shift: FE 3B C7 B8
# Right: 11101110010010010101011011011010
# Key: 00110011001101100011001000110000
# Result: 00100001011111111000100100001010
# Right after addition: 21 7F 89 0A
# Right after S-Box: EE AC 71 6D
# Right after shift: 63 8B 6F 75
# Right: 00001001110100011011011011110011
# Key: 00110000001101010101011000110001
# Result: 00111010000001110000110100100100
# Right after addition: 3A 07 0D 24
# Right after S-Box: DB 5D C9 2A
# Right after shift: EE 49 56 DA
# Right: 00000000000000000000000000000000
# Key: 00110001001100110011011000110010
# Result: 00110001001100110011011000110010
# Right after addition: 31 33 36 32
# Right after S-Box: DE 6A 1A 36
# Right after shift: 50 D1 B6 F3
# Right: 00000000000000000000000000000000
# Key: 00110001001100110011011000110010
# Result: 00110001001100110011011000110010
# Right after addition: 31 33 36 32
# Right after S-Box: DE 6A 1A 36
# Right after shift: 50 D1 B6 F3
# Right: 01010000110100011011011011110011
# Key: 00110000001101010101011000110001
# Result: 10000001000001110000110100100100
# Right after addition: 81 07 0D 24
# Right after S-Box: 4E 5D C9 2A
# Right after shift: EE 49 52 72
# Right: 11101110010010010101001001110010
# Key: 00110011001101100011001000110000
# Result: 00100001011111111000010010100010
# Right after addition: 21 7F 84 A2
# Right after S-Box: EE AC 72 46
# Right after shift: 63 92 37 75
# Right: 00110011010000111000000110000110
# Key: 00110101010101100011000100110011
# Result: 01101000100110011011001010111001
# Right after addition: 68 99 B2 B9
# Right after S-Box: 8F 79 55 78
# Right after shift: CA AB C4 7B
# Right: 00100100111000101001011000001001
# Key: 00110110001100100011000000110101
# Result: 01011011000101001100011000111110
# Right after addition: 5B 14 C6 3E
# Right after S-Box: 50 D8 3A 3F
# Right after shift: C1 D1 FA 86
# Right: 11110010100100100111101100000000
# Key: 01010110001100010011001100110110
# Result: 01001000110000111010111000110110
# Right after addition: 48 C3 AE 36
# Right after S-Box: 0F 4A A6 3B
# Right after shift: 55 31 D8 7A
# Right: 01110001110100110100111001110011
# Key: 00110010001100000011010101010110
# Result: 10100100000000111000001111001001
# Right after addition: A4 03 83 C9
# Right after S-Box: A6 5A 78 B8
# Right after shift: D3 C5 C5 32
# Right: 00100001010101111011111000110010
# Key: 00110001001100110011011000110010
# Result: 01010010100010101111010001100100
# Right after addition: 52 8A F4 64
# Right after S-Box: 52 B3 B2 5A
# Right after shift: 9D 92 D2 95
# Right: 11101100010000011001110011100110
# Key: 00110001001100110011011000110010
# Result: 00011101011101001101001100011000
# Right after addition: 1D 74 D3 18
# Right after S-Box: 7A A8 E8 8E
# Right after shift: 47 44 73 D5
# Right: 01100110000100111100110111100111
# Key: 00110010001100000011010101010110
# Result: 10011000010001000000001100111101
# Right after addition: 98 44 03 3D
# Right after S-Box: FF 98 C8 33
# Right after shift: C6 41 9F FC
# Right: 00101010000000000000001100011010
# Key: 01010110001100010011001100110110
# Result: 10000000001100010011011001010000
# Right after addition: 80 31 36 50
# Right after S-Box: 48 6F 1A AC
# Right after shift: 78 D5 62 43
# Right: 00011110110001101010111110100100
# Key: 00110110001100100011000000110101
# Result: 01010100111110001101111111011001
# Right after addition: 54 F8 DF D9
# Right after S-Box: 56 00 E0 D8
# Right after shift: 07 06 C2 B0
# Right: 00101101000001101100000110101010
# Key: 00110101010101100011000100110011
# Result: 01100010010111001111001011011101
# Right after addition: 62 5C F2 DD
# Right after S-Box: 82 2B B5 D3
# Right after shift: 5D AE 9C 11
# Right: 01000011011010000011001110110101
# Key: 00110011001101100011001000110000
# Result: 01110110100111100110010111100101
# Right after addition: 76 9E 65 E5
# Right after S-Box: 31 72 FF 05
# Right after shift: 97 F8 29 8B
# Right: 10111010111111101110100000100001
# Key: 00110000001101010101011000110001
# Result: 11101011001101000011111001010010
# Right after addition: EB 34 3E 52
# Right after S-Box: B0 68 16 A6
# Right after shift: 40 B5 35 83
# Right: 00000011110111010000011000110110
# Key: 00110001001100110011011000110010
# Result: 00110101000100000011110001101000
# Right after addition: 35 10 3C 68
# Right after S-Box: D9 D7 1C 5E
# Right after shift: B8 E2 F6 CE
# Right: 00000010000111000001111011101111
# Key: 00110001001100110011011000110010
# Result: 00110011010011110101010100100001
# Right after addition: 33 4F 55 21
# Right after S-Box: D5 9C 4F 24
# Right after shift: E2 79 26 AC
# Right: 11100001101001000010000010011010
# Key: 00110010001100000011010101010110
# Result: 00010011110101000101010111110000
# Right after addition: 13 D4 55 F0
# Right after S-Box: 75 38 4F FC
# Right after shift: C2 7F E3 A9
# Right: 11000000011000111111110101000110
# Key: 01010110001100010011001100110110
# Result: 00010110100101010011000001111100
# Right after addition: 16 95 30 7C
# Right after S-Box: 71 71 1B C0
# Right after shift: 88 DE 03 8B
# Right: 01101001011110100010001100010001
# Key: 00110110001100100011000000110101
# Result: 10011111101011000101001101000110
# Right after addition: 9F AC 53 46
# Right after S-Box: F7 8B 48 9B
# Right after shift: 5A 44 DF BC
# Right: 10011010001001110010001011111010
# Key: 00110101010101100011000100110011
# Result: 11001111011111010101010000101101
# Right after addition: CF 7D 54 2D
# Right after S-Box: 97 A4 42 23
# Right after shift: 22 11 1C BD
# Right: 01001011011010110011111110101100
# Key: 00110011001101100011001000110000
# Result: 01111110101000010111000111011100
# Right after addition: 7E A1 71 DC
# Right after S-Box: 33 8F 63 D0
# Right after shift: 7B 1E 81 9C
# Right: 11100001001110011010001101100110
# Key: 00110000001101010101011000110001
# Result: 00010001011011101111100110010111
# Right after addition: 11 6E F9 97
# Right after S-Box: 7E C2 B1 E9
# Right after shift: 15 8F 4B F6
# Right: 01011110111001000111010001011010
# Key: 00110001001100110011011000110010
# Result: 10010000000101111010101010001100
# Right after addition: 90 17 AA 8C
# Right after S-Box: F8 DD A7 10
# Right after shift: ED 38 87 C6
# Right: 00001100000000010010010010100000
# Key: 00110001001100110011011000110010
# Result: 00111101001101000101101011010010
# Right after addition: 3D 34 5A D2
# Right after S-Box: DA 68 47 D6
# Right after shift: 42 3E B6 D3
# Right: 00011100110110101100001010001001
# Key: 00110010001100000011010101010110
# Result: 01001111000010101111011111011111
# Right after addition: 4F 0A F7 DF
# Right after S-Box: 07 53 BD D1
# Right after shift: 9D EE 88 3A
# Right: 10010001111011111010110010011010
# Key: 01010110001100010011001100110110
# Result: 11101000001000001101111111010000
# Right after addition: E8 20 DF D0
# Right after S-Box: BF F7 E0 DC
# Right after shift: BF 06 E5 FF
# Right: 10100011110111000010011101110110
# Key: 00110110001100100011000000110101
# Result: 11011010000011100101011110101011
# Right after addition: DA 0E 57 AB
# Right after S-Box: CB 52 4D 47
# Right after shift: 92 6A 3E 5A
# Right: 00000011100001011001001011000000
# Key: 00110101010101100011000100110011
# Result: 00111000110110111100001111110011
# Right after addition: 38 DB C3 F3
# Right after S-Box: DF 3E 38 F2
# Right after shift: F1 C7 96 F9
# Right: 01010010000110111011000110001111
# Key: 00110011001101100011001000110000
# Result: 10000101010100011110001110111111
# Right after addition: 85 51 E3 BF
# Right after S-Box: 49 2F 98 71
# Right after shift: 7C C3 8A 49
# Right: 01111111010001100001100010001001
# Key: 00110000001101010101011000110001
# Result: 10101111011110110110111010111010
# Right after addition: AF 7B 6E BA
# Right after S-Box: A7 AE F6 7D
# Right after shift: 77 B3 ED 3D
# Right: 00100101101010000101110010110010
# Key: 00110001001100110011011000110010
# Result: 01010110110110111001001011100100
# Right after addition: 56 DB 92 E4
# Right after S-Box: 51 3E 05 0A
# Right after shift: F0 28 52 89
# VUONG_DUYnJ%¨\²

# %%
# result for block 1
block = blocks[0]
key_for_rounds = generate_key_for_rounds(key_256b)

left, right, key_round = block[:32], block[32:], key_for_rounds[0]
print("Round 0:")
print(f"Left: {bin_to_hex(left)}")
print(f"Right: {bin_to_hex(right)}")
print(f"Key: {bin_to_hex(key_round)}")
print()
left, right = MAGMA_round(left, right, key_round)
print("Round 1:")
print(f"Left: {bin_to_hex(left)}")
print(f"Right: {bin_to_hex(right)}")
print(f"Key: {bin_to_hex(key_round)}")
print()
# Out:
# Round 0:
# Left: 56 55 4F 4E
# Right: 47 5F 44 55
# Key: 31 33 36 32
#
# Right: 01000111010111110100010001010101
# Key: 00110001001100110011011000110010
# Result: 01111000100100100111101010000111
# Right after addition: 78 92 7A 87
# Right after S-Box: 3F 75 67 19
# Right after shift: AB 38 C9 FB
# Round 1:
# Left: 47 5F 44 55
# Right: FD 6D 86 B5
# Key: 31 33 36 32
